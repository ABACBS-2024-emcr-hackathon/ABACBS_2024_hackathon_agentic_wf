# %%
import gzip
import urllib.request
import requests
import json
import polars as pl
import openai

# %%
def fetch_geo_soft_http(accession):
    prefix = accession[:6] + "nnn"
    url = f"https://ftp.ncbi.nlm.nih.gov/geo/series/{prefix}/{accession}/soft/{accession}_family.soft.gz"
    
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with gzip.open(response.raw, 'rt') as f:
            return f.read()
    else:
        print(f"Error: HTTP {response.status_code}")
        return None


def parse_soft_to_json(soft_text):
    data = {}
    current_section = None
    sample_list = []  # List to hold all samples

    for line in soft_text.splitlines():
        if line.startswith('^'):
            # Check for new sections, including series and samples
            tag, value = line.split(" = ", 1)
            section_name = tag[1:].strip().lower()  # Remove "^" and make lowercase

            if section_name == "sample":
                # Initialize new sample dictionary
                current_sample = {"id": value}
                sample_list.append(current_sample)
                current_section = "sample"
            else:
                # Handle other sections (e.g., database, series)
                data[section_name] = {"id": value}
                current_section = section_name

        elif line.startswith('!'):
            # Attribute within a section or sample
            if current_section:
                tag, value = line.split(" = ", 1)
                attribute_name = tag[1:].strip().lower()
                
                # Store attributes in the current sample if we're in a sample section
                if current_section == "sample":
                    if attribute_name in current_sample:
                        # Handle multiple values for the same attribute
                        if isinstance(current_sample[attribute_name], list):
                            current_sample[attribute_name].append(value)
                        else:
                            current_sample[attribute_name] = [current_sample[attribute_name], value]
                    else:
                        current_sample[attribute_name] = value
                else:
                    # Store attributes in the general section (e.g., series)
                    if attribute_name in data[current_section]:
                        if isinstance(data[current_section][attribute_name], list):
                            data[current_section][attribute_name].append(value)
                        else:
                            data[current_section][attribute_name] = [data[current_section][attribute_name], value]
                    else:
                        data[current_section][attribute_name] = value

    # Add samples to main data if there are any
    if sample_list:
        data["samples"] = sample_list

    return data

def get_series_summary(samples_json):
    series_info = samples_json.get('series')
    series_summary = {
        'title': series_info.get('series_title'),
        'summary': series_info.get('series_summary'),
        'overall_design': ' '.join(series_info.get('series_overall_design')),
        'pubmed_id': series_info.get('pubmed_id'),
        'platform_id': series_info.get('platform_id'),
        'platform_taxid': series_info.get('platform_taxid'),
        'platform_organism': series_info.get('platform_organism'),
    }

    return series_summary

def extract_experimental_details(samples_json):
    experiment_details = []

    for sample in samples_json:
        # Extract key experimental details from each sample
        sample_details = {
            'id': sample.get('id'),
            'title': sample.get('sample_title'),
            'tissue': next((char for char in sample.get('sample_characteristics_ch1', []) if 'tissue' in char), None),
            'organism': sample.get('sample_organism_ch1'),
            'molecule': sample.get('sample_molecule_ch1'),
            'platform': sample.get('sample_platform_id'),
            'sequencing_instrument': sample.get('sample_instrument_model'),
            'library_strategy': sample.get('sample_library_strategy'),
            'library_source': sample.get('sample_library_source'),
            'data_processing': sample.get('sample_data_processing', []),
            'sample_characteristics': sample.get('sample_characteristics_ch1', []),
        }
        
        # sample characteristics is a list of strings, so we need to parse it to a dictionary
        sample_details['sample_characteristics'] = {char.split(': ')[0]: char.split(': ')[1] for char in sample_details['sample_characteristics']}

        # Filter out None values to keep only available details
        sample_details = {k: v for k, v in sample_details.items() if v}
        experiment_details.append(sample_details)

    return experiment_details

def get_geo_summary(accession):
    soft_data = fetch_geo_soft_http(accession)
    soft_json = parse_soft_to_json(soft_data)
    return {
        'series_summary': get_series_summary(soft_json),
        'samples': extract_experimental_details(soft_json['samples'])
    }

# %%
client = openai.Client(api_key="")
def ask_openai(question, context, model="gpt-4o-mini"):
    response = client.chat.completions.create(
        model=model,
        messages=[
            {'role': 'system', 'content': f"{context}"},
            {'role': 'user', 'content': f"{question}"},
        ]
    )
    return response.choices[0].message.content

# %%
for accession in ['GSE265975', 'GSE231649', 'GSE255535']:
    geo_sample_info = get_geo_summary(accession)
    group_field = ask_openai(
        "Tell the dictionary key that corresponds to the experimental group or treatment condition of the sample. Return only the key without any quotation marks.",
        f"{geo_sample_info['samples'][0]['sample_characteristics']}"
    )
    print(f"Accession: {accession}")
    print(f"Sample Characteristics: {geo_sample_info['samples'][0]['sample_characteristics']}")
    print(f"Experimental Group Key: {group_field}")

    unique_treatments = set(sorted([x.get('sample_characteristics').get(group_field) for x in geo_sample_info.get("samples")]))

    print(f"Unique Treatments: {unique_treatments}")

    series_summary = geo_sample_info.get("series_summary")
    treatment_group_info = ask_openai(
        f"Describe each of the unique treatments in the dataset. The treatments are: {', '.join(unique_treatments)}",
        f"This is the series summary:\n{series_summary}"
    )

    print(treatment_group_info)
    
    print(pl.DataFrame(geo_sample_info.get("samples")).head(6))
    print("----\n")
# Out:
# Accession: GSE265975
# Sample Characteristics: {'tissue': 'PBMCs', 'cell type': 'PBMCs', 'group': 'HDP-high', 'time': 'd0, Pre-priming'}
# Experimental Group Key: group
# Unique Treatments: {'HC', 'HDP-high', 'HDP-low'}
# In the context of the study summarized, the unique treatments refer to the different groups of individuals being analyzed based on their health status and immune response to the mRNA BNT162b2 vaccine. Here's a description of each treatment:
#
# 1. **HC (Healthy Controls)**: This group consists of individuals without any chronic health conditions. They serve as a baseline for comparison to the other groups. The immune response of healthy controls is expected to be robust and effective after vaccination, making them a standard reference point for evaluating the vaccine's effectiveness in more vulnerable populations.
#
# 2. **HDP-high (High Responders)**: This group includes hemodialysis patients who respond well to the mRNA BNT162b2 vaccine. They demonstrate a strong humoral immune response evidenced by adequate antibody production after receiving the second dose of the vaccine. The immune response in this group is characterized by a better regulatory gene expression profile, indicating their immune system is more effective compared to the low responder group.
#
# 3. **HDP-low (Low Responders)**: This group consists of hemodialysis patients who exhibit a diminished or poor immune response to the mRNA BNT162b2 vaccine. Their humoral response is significantly lower after the second dose, and transcriptomic analyses revealed significant differences in gene expression related to immune function. This group shows characteristics such as lower B cell abundance, impaired CD4 T cell proliferation, and heightened inflammation pathways, reflecting challenges in their immune systems due to conditions like lymphopenia and chronic inflammation.
#
# Overall, these treatments reflect the varying capabilities of the immune response in individuals with different health statuses, particularly focusing on the challenges faced by hemodialysis patients.
# shape: (6, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ title     ┆ tissue    ┆ organism  ┆ … ┆ library_s ┆ library_s ┆ data_proc ┆ sample_c │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ trategy   ┆ ource     ┆ essing    ┆ haracter │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ istics   │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ str       ┆ list[str] ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ struct[4 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ GSM823847 ┆ PAT14,    ┆ tissue:   ┆ Homo      ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["Trimmin ┆ {"PBMCs" │
# │ 4         ┆ HDP-high, ┆ PBMCs     ┆ sapiens   ┆   ┆           ┆ tomic     ┆ g and     ┆ ,"PBMCs" │
# │           ┆ d0        ┆           ┆           ┆   ┆           ┆           ┆ removal   ┆ ,"HDP-hi │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ of low-…  ┆ gh","d…  │
# │ GSM823847 ┆ PAT14,    ┆ tissue:   ┆ Homo      ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["Trimmin ┆ {"PBMCs" │
# │ 5         ┆ HDP-high, ┆ PBMCs     ┆ sapiens   ┆   ┆           ┆ tomic     ┆ g and     ┆ ,"PBMCs" │
# │           ┆ d21       ┆           ┆           ┆   ┆           ┆           ┆ removal   ┆ ,"HDP-hi │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ of low-…  ┆ gh","d…  │
# │ GSM823847 ┆ PAT14,    ┆ tissue:   ┆ Homo      ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["Trimmin ┆ {"PBMCs" │
# │ 6         ┆ HDP-high, ┆ PBMCs     ┆ sapiens   ┆   ┆           ┆ tomic     ┆ g and     ┆ ,"PBMCs" │
# │           ┆ d28       ┆           ┆           ┆   ┆           ┆           ┆ removal   ┆ ,"HDP-hi │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ of low-…  ┆ gh","d…  │
# │ GSM823847 ┆ PAT19,    ┆ tissue:   ┆ Homo      ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["Trimmin ┆ {"PBMCs" │
# │ 7         ┆ HDP-low,  ┆ PBMCs     ┆ sapiens   ┆   ┆           ┆ tomic     ┆ g and     ┆ ,"PBMCs" │
# │           ┆ d0        ┆           ┆           ┆   ┆           ┆           ┆ removal   ┆ ,"HDP-lo │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ of low-…  ┆ w","d0…  │
# │ GSM823847 ┆ PAT19,    ┆ tissue:   ┆ Homo      ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["Trimmin ┆ {"PBMCs" │
# │ 8         ┆ HDP-low,  ┆ PBMCs     ┆ sapiens   ┆   ┆           ┆ tomic     ┆ g and     ┆ ,"PBMCs" │
# │           ┆ d21       ┆           ┆           ┆   ┆           ┆           ┆ removal   ┆ ,"HDP-lo │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ of low-…  ┆ w","d2…  │
# │ GSM823847 ┆ PAT19,    ┆ tissue:   ┆ Homo      ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["Trimmin ┆ {"PBMCs" │
# │ 9         ┆ HDP-low,  ┆ PBMCs     ┆ sapiens   ┆   ┆           ┆ tomic     ┆ g and     ┆ ,"PBMCs" │
# │           ┆ d28       ┆           ┆           ┆   ┆           ┆           ┆ removal   ┆ ,"HDP-lo │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ of low-…  ┆ w","d2…  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
# ----
#
# Accession: GSE231649
# Sample Characteristics: {'tissue': 'Spleen', 'cell line': 'Primary', 'cell type': 'GC-B cells', 'genotype': 'WT', 'treatment': '5 days after HEL3x-SRBC immunization'}
# Experimental Group Key: treatment
# Unique Treatments: {'5 days after HEL3x-SRBC immunization'}
# In the dataset, the unique treatment described is the timeframe following the immunization of congenic mice with HEL3x-SRBC (sheep red blood cells) conjugate. Specifically, this treatment involves observing the effects and characteristics of the germinal center (GC) B cells that have been positively selected in the light zone (LZ) of the GC, 5 days after the immunization process.
#
# The significance of this 5-day period post-immunization is crucial as it allows for the analysis of the transcriptomic profiles of the GC B cells, which will reflect the responses and adaptations of these cells to the immunization with the HEL3x-SRBC. The transcriptomic analysis will provide insights into the biological implications of the presence or absence of miR-155 in these B cells, as well as their associated molecular pathways and immune responses activated during this early phase of the germinal center reaction.
#
# This treatment thus serves as a key time point to understand the dynamics of B cell activation, differentiation, and the role of miR-155 in regulating these processes within the context of immune responses.
# shape: (6, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ title     ┆ tissue    ┆ organism  ┆ … ┆ library_s ┆ library_s ┆ data_proc ┆ sample_c │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ trategy   ┆ ource     ┆ essing    ┆ haracter │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ istics   │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ str       ┆ list[str] ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ struct[5 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ GSM729520 ┆ cMyc-GFP+ ┆ tissue:   ┆ Mus       ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["The     ┆ {"Spleen │
# │ 9         ┆ LZ GC-B   ┆ Spleen    ┆ musculus  ┆   ┆           ┆ tomic     ┆ RSEM      ┆ ","Prima │
# │           ┆ cells,    ┆           ┆           ┆   ┆           ┆           ┆ package   ┆ ry","GC- │
# │           ┆ WT1       ┆           ┆           ┆   ┆           ┆           ┆ (version  ┆ B cell…  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 1.…       ┆          │
# │ GSM729521 ┆ cMyc-GFP+ ┆ tissue:   ┆ Mus       ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["The     ┆ {"Spleen │
# │ 0         ┆ LZ GC-B   ┆ Spleen    ┆ musculus  ┆   ┆           ┆ tomic     ┆ RSEM      ┆ ","Prima │
# │           ┆ cells,    ┆           ┆           ┆   ┆           ┆           ┆ package   ┆ ry","GC- │
# │           ┆ WT2       ┆           ┆           ┆   ┆           ┆           ┆ (version  ┆ B cell…  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 1.…       ┆          │
# │ GSM729521 ┆ cMyc-GFP+ ┆ tissue:   ┆ Mus       ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["The     ┆ {"Spleen │
# │ 1         ┆ LZ GC-B   ┆ Spleen    ┆ musculus  ┆   ┆           ┆ tomic     ┆ RSEM      ┆ ","Prima │
# │           ┆ cells,    ┆           ┆           ┆   ┆           ┆           ┆ package   ┆ ry","GC- │
# │           ┆ WT3       ┆           ┆           ┆   ┆           ┆           ┆ (version  ┆ B cell…  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 1.…       ┆          │
# │ GSM729521 ┆ cMyc-GFP+ ┆ tissue:   ┆ Mus       ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["The     ┆ {"Spleen │
# │ 2         ┆ LZ GC-B   ┆ Spleen    ┆ musculus  ┆   ┆           ┆ tomic     ┆ RSEM      ┆ ","Prima │
# │           ┆ cells,    ┆           ┆           ┆   ┆           ┆           ┆ package   ┆ ry","GC- │
# │           ┆ WT4       ┆           ┆           ┆   ┆           ┆           ┆ (version  ┆ B cell…  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 1.…       ┆          │
# │ GSM729521 ┆ cMyc-GFP+ ┆ tissue:   ┆ Mus       ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["The     ┆ {"Spleen │
# │ 3         ┆ LZ GC-B   ┆ Spleen    ┆ musculus  ┆   ┆           ┆ tomic     ┆ RSEM      ┆ ","Prima │
# │           ┆ cells,    ┆           ┆           ┆   ┆           ┆           ┆ package   ┆ ry","GC- │
# │           ┆ WT5       ┆           ┆           ┆   ┆           ┆           ┆ (version  ┆ B cell…  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 1.…       ┆          │
# │ GSM729521 ┆ cMyc-GFP+ ┆ tissue:   ┆ Mus       ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["The     ┆ {"Spleen │
# │ 4         ┆ LZ GC-B   ┆ Spleen    ┆ musculus  ┆   ┆           ┆ tomic     ┆ RSEM      ┆ ","Prima │
# │           ┆ cells,    ┆           ┆           ┆   ┆           ┆           ┆ package   ┆ ry","GC- │
# │           ┆ KO1       ┆           ┆           ┆   ┆           ┆           ┆ (version  ┆ B cell…  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 1.…       ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
# ----
#
# Accession: GSE255535
# Sample Characteristics: {'cell line': '387 GSC', 'cell type': 'Glioblastoma stem cells', 'treatment': 'shCONT'}
# Experimental Group Key: treatment
# Unique Treatments: {'shMDH2-03_set', 'shMDH2_03', 'shCONT', 'shMDH2_63', 'ShMDH2-63_set'}
# The dataset includes the following unique treatments, each related to targeting malate dehydrogenase 2 (MDH2) in glioblastoma stem cells (GSCs):
#
# 1. **shMDH2-03_set**: This treatment consists of a set of shRNAs designed to target and knock down the expression of MDH2. The "set" implies that it may include multiple independent shRNAs aimed at ensuring effective and comprehensive silencing of MDH2.
#
# 2. **shMDH2_03**: This treatment involves a specific shRNA targeting MDH2. It is likely one of the shRNAs from the shMDH2-03_set, designed to decrease the expression of MDH2 and study its effects on GSC activity, proliferation, and metabolism.
#
# 3. **shCONT**: This treatment is a nontargeting control shRNA (short hairpin RNA). It is used as a baseline comparison to evaluate the effects of the MDH2-targeting shRNAs. The shCONT should have no impact on MDH2 expression, allowing researchers to attribute any observed effects specifically to the MDH2 knockdown.
#
# 4. **shMDH2_63**: Similar to shMDH2_03, this treatment represents another specific shRNA targeting MDH2. It is likely part of a different or complementary set for knocking down MDH2 expression, aimed at investigating its role in GSCs.
#
# 5. **ShMDH2-63_set**: This treatment includes a set of shRNAs, presumably including the shMDH2_63, targeting MDH2. Like the shMDH2-03_set, this set would consist of multiple shRNAs designed for effective MDH2 silencing, allowing for reliability in the assessment of MDH2's function in GSCs.
#
# These treatments are key components in the study of metabolic regulation and changes in the epitranscriptome associated with MDH2 in glioblastoma stem cells.
# shape: (6, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id        ┆ title     ┆ organism  ┆ molecule  ┆ … ┆ library_s ┆ library_s ┆ data_proc ┆ sample_c │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ trategy   ┆ ource     ┆ essing    ┆ haracter │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ istics   │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ str       ┆ list[str] ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ struct[3 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ GSM807401 ┆ GSCs,     ┆ Homo      ┆ total RNA ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["CLC     ┆ {"387    │
# │ 7         ┆ shCONT    ┆ sapiens   ┆           ┆   ┆           ┆ tomic     ┆ Genomics  ┆ GSC","Gl │
# │           ┆ set 1     ┆           ┆           ┆   ┆           ┆           ┆ Workbench ┆ ioblasto │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ v 11.…    ┆ ma stem  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ …        │
# │ GSM807401 ┆ GSCs, shM ┆ Homo      ┆ total RNA ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["CLC     ┆ {"387    │
# │ 8         ┆ DH2-03_se ┆ sapiens   ┆           ┆   ┆           ┆ tomic     ┆ Genomics  ┆ GSC","Gl │
# │           ┆ t 1       ┆           ┆           ┆   ┆           ┆           ┆ Workbench ┆ ioblasto │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ v 11.…    ┆ ma stem  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ …        │
# │ GSM807401 ┆ GSCs, ShM ┆ Homo      ┆ total RNA ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["CLC     ┆ {"387    │
# │ 9         ┆ DH2-63_se ┆ sapiens   ┆           ┆   ┆           ┆ tomic     ┆ Genomics  ┆ GSC","Gl │
# │           ┆ t 1       ┆           ┆           ┆   ┆           ┆           ┆ Workbench ┆ ioblasto │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ v 11.…    ┆ ma stem  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ …        │
# │ GSM807402 ┆ GSCs,     ┆ Homo      ┆ total RNA ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["CLC     ┆ {"387    │
# │ 0         ┆ shCONT    ┆ sapiens   ┆           ┆   ┆           ┆ tomic     ┆ Genomics  ┆ GSC","Gl │
# │           ┆ set 2     ┆           ┆           ┆   ┆           ┆           ┆ Workbench ┆ ioblasto │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ v 11.…    ┆ ma stem  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ …        │
# │ GSM807402 ┆ GSCs, shM ┆ Homo      ┆ total RNA ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["CLC     ┆ {"387    │
# │ 1         ┆ DH2-03_se ┆ sapiens   ┆           ┆   ┆           ┆ tomic     ┆ Genomics  ┆ GSC","Gl │
# │           ┆ t 2       ┆           ┆           ┆   ┆           ┆           ┆ Workbench ┆ ioblasto │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ v 11.…    ┆ ma stem  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ …        │
# │ GSM807402 ┆ GSCs, ShM ┆ Homo      ┆ total RNA ┆ … ┆ RNA-Seq   ┆ transcrip ┆ ["CLC     ┆ {"387    │
# │ 2         ┆ DH2-63_se ┆ sapiens   ┆           ┆   ┆           ┆ tomic     ┆ Genomics  ┆ GSC","Gl │
# │           ┆ t 2       ┆           ┆           ┆   ┆           ┆           ┆ Workbench ┆ ioblasto │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ v 11.…    ┆ ma stem  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ …        │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
# ----
